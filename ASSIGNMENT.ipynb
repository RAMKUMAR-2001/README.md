# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **RAMKUMAR BENDALAM** <br> student

# %% [markdown]
# I am interested in data science because want to explore how data works by AI and machine learning

# %% [markdown]
# ### my code is about of two numbers by using variables

# %%
a=1
b=2
c=a+b
print(c)
# Out:
# 3

# %% [markdown]
# - VISAKHAPATNAM
# - HYDERABAD
#
# 1.CANADA
#
# __(https://www.ibm.com/in-en/cloud/watson-studio)__
